# %% [markdown]
# # Strenge

# %% [markdown]
# ## Tildel (assign) en streng til en variabel:
# Når man tildeler en streng (string) til en variabel, gør man det ved at bruge variablens navn efterfulgt af et lighedstegn og strengen. Man kan også sige det på den måde, at man gemmer en værdi i variabelnavnet.
#
# F.eks. url = "https://sciencedata.dk/shared/b01a61ba6a4a634fd687668d4e3ab887?download"
#
# Url-variablen indeholder værdien til højre for lighedstegnet.

# %%
import urllib.request
url = "https://sciencedata.dk/shared/b01a61ba6a4a634fd687668d4e3ab887?download"
raw_text = urllib.request.urlopen(url).read().decode(encoding='utf-8-sig')

# %%
raw_text
# Out:
# 'ASHPUTTEL\r\r\n\r\r\n\r\r\nThe wife of a rich man fell sick; and when she felt that her end drew\r\r\nnigh, she called her only daughter to her bed-side, and said, ‘Always be\r\r\na good girl, and I will look down from heaven and watch over you.’ Soon\r\r\nafterwards she shut her eyes and died, and was buried in the garden;\r\r\nand the little girl went every day to her grave and wept, and was always\r\r\ngood and kind to all about her. And the snow fell and spread a beautiful\r\r\nwhite covering over the grave; but by the time the spring came, and the\r\r\nsun had melted it away again, her father had married another wife. This\r\r\nnew wife had two daughters of her own, that she brought home with her;\r\r\nthey were fair in face but foul at heart, and it was now a sorry time\r\r\nfor the poor little girl. ‘What does the good-for-nothing want in the\r\r\nparlour?’ said they; ‘they who would eat bread should first earn it;\r\r\naway with the kitchen-maid!’ Then they took away her fine clothes, and\r\r\ngave her an old grey frock to put on, and laughed at her, and turned her\r\r\ninto the kitchen.\r\r\n\r\r\nThere she was forced to do hard work; to rise early before daylight, to\r\r\nbring the water, to make the fire, to cook and to wash. Besides that,\r\r\nthe sisters plagued her in all sorts of ways, and laughed at her. In the\r\r\nevening when she was tired, she had no bed to lie down on, but was made\r\r\nto lie by the hearth among the ashes; and as this, of course, made her\r\r\nalways dusty and dirty, they called her Ashputtel.\r\r\n\r\r\nIt happened once that the father was going to the fair, and asked his\r\r\nwife’s daughters what he should bring them. ‘Fine clothes,’ said the\r\r\nfirst; ‘Pearls and diamonds,’ cried the second. ‘Now, child,’ said he\r\r\nto his own daughter, ‘what will you have?’ ‘The first twig, dear\r\r\nfather, that brushes against your hat when you turn your face to come\r\r\nhomewards,’ said she. Then he bought for the first two the fine clothes\r\r\nand pearls and diamonds they had asked for: and on his way home, as he\r\r\nrode through a green copse, a hazel twig brushed against him, and almost\r\r\npushed off his hat: so he broke it off and brought it away; and when he\r\r\ngot home he gave it to his daughter. Then she took it, and went to\r\r\nher mother’s grave and planted it there; and cried so much that it was\r\r\nwatered with her tears; and there it grew and became a fine tree. Three\r\r\ntimes every day she went to it and cried; and soon a little bird came\r\r\nand built its nest upon the tree, and talked with her, and watched over\r\r\nher, and brought her whatever she wished for.\r\r\n\r\r\nNow it happened that the king of that land held a feast, which was to\r\r\nlast three days; and out of those who came to it his son was to choose\r\r\na bride for himself. Ashputtel’s two sisters were asked to come; so they\r\r\ncalled her up, and said, ‘Now, comb our hair, brush our shoes, and tie\r\r\nour sashes for us, for we are going to dance at the king’s feast.’\r\r\nThen she did as she was told; but when all was done she could not help\r\r\ncrying, for she thought to herself, she should so have liked to have\r\r\ngone with them to the ball; and at last she begged her mother very hard\r\r\nto let her go. ‘You, Ashputtel!’ said she; ‘you who have nothing to\r\r\nwear, no clothes at all, and who cannot even dance--you want to go to\r\r\nthe ball? And when she kept on begging, she said at last, to get rid of\r\r\nher, ‘I will throw this dishful of peas into the ash-heap, and if in\r\r\ntwo hours’ time you have picked them all out, you shall go to the feast\r\r\ntoo.’\r\r\n\r\r\nThen she threw the peas down among the ashes, but the little maiden ran\r\r\nout at the back door into the garden, and cried out:\r\r\n\r\r\n ‘Hither, hither, through the sky,\r\r\n  Turtle-doves and linnets, fly!\r\r\n  Blackbird, thrush, and chaffinch gay,\r\r\n  Hither, hither, haste away!\r\r\n  One and all come help ...

# %% [markdown]
# ## En tekststreng er en række¶
# En tekststreng er en række elementer, der repræsenterer Unicode-tegn.
#
# Firkantede parenteser giver adgang til elementer i strengen.
#
# F.eks. returnerer raw_text[0] tegnet på index position 1 (husk, at det første tegn har position 0)

# %%
raw_text[0]
# Out:
# 'A'

# %% [markdown]
# ## At slice
#
# Du kan returnere en række tegn ved at bruge en slice-teknik, der består i at du angiver et startindex og et slutindex, adskilt af et et kolon
#
# F.eks. henter raw_text[0:100] elementerne fra startindext 0 til slutindex 100, der ikke er inkluderet.

# %%
raw_text[0:100]
# Out:
# 'ASHPUTTEL\r\r\n\r\r\n\r\r\nThe wife of a rich man fell sick; and when she felt that her end drew\r\r\nnigh, she '

# %% [markdown]
# Ved at udelade slutindekset vil rækken gå til slutningen:

# %%
raw_text[11000:]
# Out:
# '\nand went to the king’s son. Then he took her for his bride, and set her\r\r\nbeside him on his horse, and rode away with her homewards.\r\r\n\r\r\nBut on their way home they had to pass by the hazel-tree that Ashputtel\r\r\nhad planted; and on the branch sat a little dove singing:\r\r\n\r\r\n ‘Back again! back again! look to the shoe!\r\r\n  The shoe is too small, and not made for you!\r\r\n  Prince! prince! look again for thy bride,\r\r\n  For she’s not the true one that sits by thy side.’\r\r\n\r\r\nThen the prince got down and looked at her foot; and he saw, by the\r\r\nblood that streamed from it, what a trick she had played him. So he\r\r\nturned his horse round, and brought the false bride back to her home,\r\r\nand said, ‘This is not the right bride; let the other sister try and put\r\r\non the slipper.’ Then she went into the room and got her foot into the\r\r\nshoe, all but the heel, which was too large. But her mother squeezed it\r\r\nin till the blood came, and took her to the king’s son: and he set her\r\r\nas his bride by his side on his horse, and rode away with her.\r\r\n\r\r\nBut when they came to the hazel-tree the little dove sat there still,\r\r\nand sang:\r\r\n\r\r\n ‘Back again! back again! look to the shoe!\r\r\n  The shoe is too small, and not made for you!\r\r\n  Prince! prince! look again for thy bride,\r\r\n  For she’s not the true one that sits by thy side.’\r\r\n\r\r\nThen he looked down, and saw that the blood streamed so much from the\r\r\nshoe, that her white stockings were quite red. So he turned his horse\r\r\nand brought her also back again. ‘This is not the true bride,’ said he\r\r\nto the father; ‘have you no other daughters?’ ‘No,’ said he; ‘there is\r\r\nonly a little dirty Ashputtel here, the child of my first wife; I am\r\r\nsure she cannot be the bride.’ The prince told him to send her. But the\r\r\nmother said, ‘No, no, she is much too dirty; she will not dare to show\r\r\nherself.’ However, the prince would have her come; and she first washed\r\r\nher face and hands, and then went in and curtsied to him, and he reached\r\r\nher the golden slipper. Then she took her clumsy shoe off her left foot,\r\r\nand put on the golden slipper; and it fitted her as if it had been made\r\r\nfor her. And when he drew near and looked at her face he knew her, and\r\r\nsaid, ‘This is the right bride.’ But the mother and both the sisters\r\r\nwere frightened, and turned pale with anger as he took Ashputtel on his\r\r\nhorse, and rode away with her. And when they came to the hazel-tree, the\r\r\nwhite dove sang:\r\r\n\r\r\n ‘Home! home! look at the shoe!\r\r\n  Princess! the shoe was made for you!\r\r\n  Prince! prince! take home thy bride,\r\r\n  For she is the true one that sits by thy side!’\r\r\n\r\r\nAnd when the dove had done its song, it came flying, and perched upon\r\r\nher right shoulder, and so went home with her.'

# %% [markdown]
# Du kan også bruge negative indeks til at slice til enden af strengen:

# %%
raw_text[-100:]
# Out:
# 'had done its song, it came flying, and perched upon\r\r\nher right shoulder, and so went home with her.'

# %% [markdown]
# ## At loope over en tekststreng
# Med et loop kan vi også løbe gennem elementerne i en streng.

# %%
new_text = raw_text[0:10]
for i in new_text:
    print(i)
# Out:
# A
# S
# H
# P
# U
# T
# T
# E
# L

# %% [markdown]
# ## Funktionen len() og strengmetoder
# ### len()
# Længden på en streng kan du finde vha. len() funktionen.

# %%
lenght = len(raw_text)
print (f'Ashputtel is {lenght} signs long ( with whitespace ) ')
# Out:
# Ashputtel is 13746 signs long ( with whitespace )

# %% [markdown]
# Ovenfor bruger vi F-strenge til at indføre indhold af variabler i en streng.

# %%
tale = 'Ashputtel'
lenght = len(raw_text)
print(f"The {tale} is {lenght} signs long ( with whitespace )")
# Out:
# The Ashputtel is 13746 signs long ( with whitespace )

# %% [markdown]
# ###  .lower() metoden
#
# .lower() returnerer en streng af små bogstaver.
#
# .upper() gør det modsatte.

# %%
lower_text = raw_text.lower()
print(lower_text[0:100])
# Out:
# ashputtel
#
#
# the wife of a rich man fell sick; and when she felt that her end drew
# nigh, she

# %% [markdown]
# ### .replace() metoden
# .replace() metoden returner en streng, hvor et specificeret tegn eller en sætning bliver erstattet af et andet specificeret tegn eller sætning.
#
# f.eks. erstatter lower_text.replace('.', ' ') alle punktummer med et mellemrum.
#
# replace metoden kan f.eks. bruges til at rense teksten for grammatiske tegn.

# %%
clean_string = lower_text.replace('.', ' ').replace(',', ' ')
clean_string
# Out:
# 'ashputtel\r\r\n\r\r\n\r\r\nthe wife of a rich man fell sick; and when she felt that her end drew\r\r\nnigh  she called her only daughter to her bed-side  and said  ‘always be\r\r\na good girl  and i will look down from heaven and watch over you ’ soon\r\r\nafterwards she shut her eyes and died  and was buried in the garden;\r\r\nand the little girl went every day to her grave and wept  and was always\r\r\ngood and kind to all about her  and the snow fell and spread a beautiful\r\r\nwhite covering over the grave; but by the time the spring came  and the\r\r\nsun had melted it away again  her father had married another wife  this\r\r\nnew wife had two daughters of her own  that she brought home with her;\r\r\nthey were fair in face but foul at heart  and it was now a sorry time\r\r\nfor the poor little girl  ‘what does the good-for-nothing want in the\r\r\nparlour?’ said they; ‘they who would eat bread should first earn it;\r\r\naway with the kitchen-maid!’ then they took away her fine clothes  and\r\r\ngave her an old grey frock to put on  and laughed at her  and turned her\r\r\ninto the kitchen \r\r\n\r\r\nthere she was forced to do hard work; to rise early before daylight  to\r\r\nbring the water  to make the fire  to cook and to wash  besides that \r\r\nthe sisters plagued her in all sorts of ways  and laughed at her  in the\r\r\nevening when she was tired  she had no bed to lie down on  but was made\r\r\nto lie by the hearth among the ashes; and as this  of course  made her\r\r\nalways dusty and dirty  they called her ashputtel \r\r\n\r\r\nit happened once that the father was going to the fair  and asked his\r\r\nwife’s daughters what he should bring them  ‘fine clothes ’ said the\r\r\nfirst; ‘pearls and diamonds ’ cried the second  ‘now  child ’ said he\r\r\nto his own daughter  ‘what will you have?’ ‘the first twig  dear\r\r\nfather  that brushes against your hat when you turn your face to come\r\r\nhomewards ’ said she  then he bought for the first two the fine clothes\r\r\nand pearls and diamonds they had asked for: and on his way home  as he\r\r\nrode through a green copse  a hazel twig brushed against him  and almost\r\r\npushed off his hat: so he broke it off and brought it away; and when he\r\r\ngot home he gave it to his daughter  then she took it  and went to\r\r\nher mother’s grave and planted it there; and cried so much that it was\r\r\nwatered with her tears; and there it grew and became a fine tree  three\r\r\ntimes every day she went to it and cried; and soon a little bird came\r\r\nand built its nest upon the tree  and talked with her  and watched over\r\r\nher  and brought her whatever she wished for \r\r\n\r\r\nnow it happened that the king of that land held a feast  which was to\r\r\nlast three days; and out of those who came to it his son was to choose\r\r\na bride for himself  ashputtel’s two sisters were asked to come; so they\r\r\ncalled her up  and said  ‘now  comb our hair  brush our shoes  and tie\r\r\nour sashes for us  for we are going to dance at the king’s feast ’\r\r\nthen she did as she was told; but when all was done she could not help\r\r\ncrying  for she thought to herself  she should so have liked to have\r\r\ngone with them to the ball; and at last she begged her mother very hard\r\r\nto let her go  ‘you  ashputtel!’ said she; ‘you who have nothing to\r\r\nwear  no clothes at all  and who cannot even dance--you want to go to\r\r\nthe ball? and when she kept on begging  she said at last  to get rid of\r\r\nher  ‘i will throw this dishful of peas into the ash-heap  and if in\r\r\ntwo hours’ time you have picked them all out  you shall go to the feast\r\r\ntoo ’\r\r\n\r\r\nthen she threw the peas down among the ashes  but the little maiden ran\r\r\nout at the back door into the garden  and cried out:\r\r\n\r\r\n ‘hither  hither  through the sky \r\r\n  turtle-doves and linnets  fly!\r\r\n  blackbird  thrush  and chaffinch gay \r\r\n  hither  hither  haste away!\r\r\n  one and all come help ...

# %% [markdown]
# ### .count metoden()

# %%
word = 'bird'
word_count = clean_string.count(word) 
word_count
# Out:
# 10

# %% [markdown]
# ###  .split() metoden
# .split() returner en ordliste, hvor hvert element er et ord (vi vender tilbage til lister). Som default splitter metoden på mellemrum, men man kan også splitte på andre tegn, som for eksempel punktum. Det ser således ud: .split(".").
#
# Split metoden bruger man f.eks. til at bygge en ordliste, og så kan man tælle, hvormange ord der er i teksten ved hjælp af ordlisten og len() funktionen,

# %%
word_list = clean_string.split()
word_list
# Out:
# ['ashputtel',
#  'the',
#  'wife',
#  'of',
#  'a',
#  'rich',
#  'man',
#  'fell',
#  'sick;',
#  'and',
#  'when',
#  'she',
#  'felt',
#  'that',
#  'her',
#  'end',
#  'drew',
#  'nigh',
#  'she',
#  'called',
#  'her',
#  'only',
#  'daughter',
#  'to',
#  'her',
#  'bed-side',
#  'and',
#  'said',
#  '‘always',
#  'be',
#  'a',
#  'good',
#  'girl',
#  'and',
#  'i',
#  'will',
#  'look',
#  'down',
#  'from',
#  'heaven',
#  'and',
#  'watch',
#  'over',
#  'you',
#  '’',
#  'soon',
#  'afterwards',
#  'she',
#  'shut',
#  'her',
#  'eyes',
#  'and',
#  'died',
#  'and',
#  'was',
#  'buried',
#  'in',
#  'the',
#  'garden;',
#  'and',
#  'the',
#  'little',
#  'girl',
#  'went',
#  'every',
#  'day',
#  'to',
#  'her',
#  'grave',
#  'and',
#  'wept',
#  'and',
#  'was',
#  'always',
#  'good',
#  'and',
#  'kind',
#  'to',
#  'all',
#  'about',
#  'her',
#  'and',
#  'the',
#  'snow',
#  'fell',
#  'and',
#  'spread',
#  'a',
#  'beautiful',
#  'white',
#  'covering',
#  'over',
#  'the',
#  'grave;',
#  'but',
#  'by',
#  'the',
#  'time',
#  'the',
#  'spring',
#  'came',
#  'and',
#  'the',
#  'sun',
#  'had',
#  'melted',
#  'it',
#  'away',
#  'again',
#  'her',
#  'father',
#  'had',
#  'married',
#  'another',
#  'wife',
#  'this',
#  'new',
#  'wife',
#  'had',
#  'two',
#  'daughters',
#  'of',
#  'her',
#  'own',
#  'that',
#  'she',
#  'brought',
#  'home',
#  'with',
#  'her;',
#  'they',
#  'were',
#  'fair',
#  'in',
#  'face',
#  'but',
#  'foul',
#  'at',
#  'heart',
#  'and',
#  'it',
#  'was',
#  'now',
#  'a',
#  'sorry',
#  'time',
#  'for',
#  'the',
#  'poor',
#  'little',
#  'girl',
#  '‘what',
#  'does',
#  'the',
#  'good-for-nothing',
#  'want',
#  'in',
#  'the',
#  'parlour?’',
#  'said',
#  'they;',
#  '‘they',
#  'who',
#  'would',
#  'eat',
#  'bread',
#  'should',
#  'first',
#  'earn',
#  'it;',
#  'away',
#  'with',
#  'the',
#  'kitchen-maid!’',
#  'then',
#  'they',
#  'took',
#  'away',
#  'her',
#  'fine',
#  'clothes',
#  'and',
#  'gave',
#  'her',
#  'an',
#  'old',
#  'grey',
#  'frock',
#  'to',
#  'put',
#  'on',
#  'and',
#  'laughed',
#  'at',
#  'her',
#  'and',
#  'turned',
#  'her',
#  'into',
#  'the',
#  'kitchen',
#  'there',
#  'she',
#  'was',
#  'forced',
#  'to',
#  'do',
#  'hard',
#  'work;',
#  'to',
#  'rise',
#  'early',
#  'before',
#  'daylight',
#  'to',
#  'bring',
#  'the',
#  'water',
#  'to',
#  'make',
#  'the',
#  'fire',
#  'to',
#  'cook',
#  'and',
#  'to',
#  'wash',
#  'besides',
#  'that',
#  'the',
#  'sisters',
#  'plagued',
#  'her',
#  'in',
#  'all',
#  'sorts',
#  'of',
#  'ways',
#  'and',
#  'laughed',
#  'at',
#  'her',
#  'in',
#  'the',
#  'evening',
#  'when',
#  'she',
#  'was',
#  'tired',
#  'she',
#  'had',
#  'no',
#  'bed',
#  'to',
#  'lie',
#  'down',
#  'on',
#  'but',
#  'was',
#  'made',
#  'to',
#  'lie',
#  'by',
#  'the',
#  'hearth',
#  'among',
#  'the',
#  'ashes;',
#  'and',
#  'as',
#  'this',
#  'of',
#  'course',
#  'made',
#  'her',
#  'always',
#  'dusty',
#  'and',
#  'dirty',
#  'they',
#  'called',
#  'her',
#  'ashputtel',
#  'it',
#  'happened',
#  'once',
#  'that',
#  'the',
#  'father',
#  'was',
#  'going',
#  'to',
#  'the',
#  'fair',
#  'and',
#  'asked',
#  'his',
#  'wife’s',
#  'daughters',
#  'what',
#  'he',
#  'should',
#  'bring',
#  'them',
#  '‘fine',
#  'clothes',
#  '’',
#  'said',
#  'the',
#  'first;',
#  '‘pearls',
#  'and',
#  'diamonds',
#  '’',
#  'cried',
#  'the',
#  'second',
#  '‘now',
#  'child',
#  '’',
#  'said',
#  'he',
#  'to',
#  'his',
#  'own',
#  'daughter',
#  '‘what',
#  'will',
#  'you',
#  'have?’',
#  '‘the',
#  'first',
#  'twig',
#  'dear',
#  'father',
#  'that',
#  'brushes',
#  'against',
#  'your',
#  'hat',
#  'when',
#  'you',
#  'turn',
#  'your',
#  'face',
#  'to',
#  'come',
#  'homewards',
#  '’',
#  'said',
#  'she',
#  'then',
#  'he',
#  'bought',
#  'for',
#  'the',
#  'first',
#  'two',
#  'the',
#  'fine',
#  'clothes',
#  'and',
#  'pearls',
#  'and',
#  'diamonds',
#  'they',
#  'had',
#  'asked',
#  'for:',
#  'and',
#  'on',
#  'his',
#  'way',
#  'home',
#  'as',
#  'he',
#  'rode',
#  'through',
#  'a',
#  'green',
#  'copse',
#  'a',
#  'hazel',
#  'twig',
#  'brushed',
#  'against',
#  'him',
#  'and',
#  'almost',
#  'pushed',
#  'off',
#  'his',
#  'hat:',
#  'so',
#  'he',
#  'broke',
#  'it',
#  'off',
#  'and',
#  'brought',
#  'it',
#  'away;',
#  'and',
#  'when',
#  'he',
#  'got',
#  'home',
#  'he',
#  'gave',
#  'it',
#  'to',
#  'his',
#  'daughter',
#  'then',
#  'she',
#  'took',
#  'it',
#  'and',
#  'went',
#  'to',
#  'her',
#  'mother’s',
#  'grave',
#  'and',
#  'planted',
#  'it',
#  'there;',
#  'and',
#  'cried',
#  'so',
#  'much',
#  'that',
#  'it',
#  'was',
#  'watered',
#  'with',
#  'her',
#  'tears;',
#  'and',
#  'there',
#  'it',
#  'grew',
#  'and',
#  'became',
#  'a',
#  'fine',
#  'tree',
#  'three',
#  'times',
#  'every',
#  'day',
#  'she',
#  'went',
#  'to',
#  'it',
#  'and',
#  'cried;',
#  'and',
#  'soon',
#  'a',
#  'little',
#  'bird',
#  'came',
#  'and',
#  'built',
#  'its',
#  'nest',
#  'upon',
#  'the',
#  'tree',
#  'and',
#  'talked',
#  'with',
#  'her',
#  'and',
#  'watched',
#  'over',
#  'her',
#  'and',
#  'brought',
#  'her',
#  'whatever',
#  'she',
#  'wished',
#  'for',
#  'now',
#  'it',
#  'happened',
#  'that',
#  'the',
#  'king',
#  'of',
#  'that',
#  'land',
#  'held',
#  'a',
#  'feast',
#  'which',
#  'was',
#  'to',
#  'last',
#  'three',
#  'days;',
#  'and',
#  'out',
#  'of',
#  'those',
#  'who',
#  'came',
#  'to',
#  'it',
#  'his',
#  'son',
#  'was',
#  'to',
#  'choose',
#  'a',
#  'bride',
#  'for',
#  'himself',
#  'ashputtel’s',
#  'two',
#  'sisters',
#  'were',
#  'asked',
#  'to',
#  'come;',
#  'so',
#  'they',
#  'called',
#  'her',
#  'up',
#  'and',
#  'said',
#  '‘now',
#  'comb',
#  'our',
#  'hair',
#  'brush',
#  'our',
#  'shoes',
#  'and',
#  'tie',
#  'our',
#  'sashes',
#  'for',
#  'us',
#  'for',
#  'we',
#  'are',
#  'going',
#  'to',
#  'dance',
#  'at',
#  'the',
#  'king’s',
#  'feast',
#  '’',
#  'then',
#  'she',
#  'did',
#  'as',
#  'she',
#  'was',
#  'told;',
#  'but',
#  'when',
#  'all',
#  'was',
#  'done',
#  'she',
#  'could',
#  'not',
#  'help',
#  'crying',
#  'for',
#  'she',
#  'thought',
#  'to',
#  'herself',
#  'she',
#  'should',
#  'so',
#  'have',
#  'liked',
#  'to',
#  'have',
#  'gone',
#  'with',
#  'them',
#  'to',
#  'the',
#  'ball;',
#  'and',
#  'at',
#  'last',
#  'she',
#  'begged',
#  'her',
#  'mother',
#  'very',
#  'hard',
#  'to',
#  'let',
#  'her',
#  'go',
#  '‘you',
#  'ashputtel!’',
#  'said',
#  'she;',
#  '‘you',
#  'who',
#  'have',
#  'nothing',
#  'to',
#  'wear',
#  'no',
#  'clothes',
#  'at',
#  'all',
#  'and',
#  'who',
#  'cannot',
#  'even',
#  'dance--you',
#  'want',
#  'to',
#  'go',
#  'to',
#  'the',
#  'ball?',
#  'and',
#  'when',
#  'she',
#  'kept',
#  'on',
#  'begging',
#  'she',
#  'said',
#  'at',
#  'last',
#  'to',
#  'get',
#  'rid',
#  'of',
#  'her',
#  '‘i',
#  'will',
#  'throw',
#  'this',
#  'dishful',
#  'of',
#  'peas',
#  'into',
#  'the',
#  'ash-heap',
#  'and',
#  'if',
#  'in',
#  'two',
#  'hours’',
#  'time',
#  'you',
#  'have',
#  'picked',
#  'them',
#  'all',
#  'out',
#  'you',
#  'shall',
#  'go',
#  'to',
#  'the',
#  'feast',
#  'too',
#  '’',
#  'then',
#  'she',
#  'threw',
#  'the',
#  'peas',
#  'down',
#  'among',
#  'the',
#  'ashes',
#  'but',
#  'the',
#  'little',
#  'maiden',
#  'ran',
#  'out',
#  'at',
#  'the',
#  'back',
#  'door',
#  'into',
#  'the',
#  'garden',
#  'and',
#  'cried',
#  'out:',
#  '‘hither',
#  'hither',
#  'through',
#  'the',
#  'sky',
#  'turtle-doves',
#  'and',
#  'linnets',
#  'fly!',
#  'blackbird',
#  'thrush',
#  'and',
#  'chaffinch',
#  'gay',
#  'hither',
#  'hither',
#  'haste',
#  'away!',
#  'one',
#  'and',
#  'all',
#  'come',
#  'help',
#  'me',
#  'quick!',
#  'haste',
#  'ye',
#  'haste',
#  'ye!--pick',
#  'pick',
#  'pick!’',
#  'then',
#  'first',
#  'came',
#  'two',
#  'white',
#  'doves',
#  'flying',
#  'in',
#  'at',
#  'the',
#  'kitchen',
#  'window;',
#  'next',
#  'came',
#  'two',
#  'turtle-doves;',
#  'and',
#  'after',
#  'them',
#  'came',
#  'all',
#  'the',
#  'little',
#  'birds',
#  'under',
#  'heaven',
#  'chirping',
#  'and',
#  'fluttering',
#  'in:',
#  'and',
#  'they',
#  'flew',
#  'down',
#  'into',
#  'the',
#  'ashes',
#  'and',
#  'the',
#  'little',
#  'doves',
#  'stooped',
#  'their',
#  'heads',
#  'down',
#  'and',
#  'set',
#  'to',
#  'work',
#  'pick',
#  'pick',
#  'pick;',
#  'and',
#  'then',
#  'the',
#  'others',
#  'began',
#  'to',
#  'pick',
#  'pick',
#  'pick:',
#  'and',
#  'among',
#  'them',
#  'all',
#  'they',
#  'soon',
#  'picked',
#  'out',
#  'all',
#  'the',
#  'good',
#  'grain',
#  'and',
#  'put',
#  'it',
#  'into',
#  'a',
#  'dish',
#  'but',
#  'left',
#  'the',
#  'ashes',
#  'long',
#  'before',
#  'the',
#  'end',
#  'of',
#  'the',
#  'hour',
#  'the',
#  'work',
#  'was',
#  'quite',
#  'done',
#  'and',
#  'all',
#  'flew',
#  'out',
#  'again',
#  'at',
#  'the',
#  'windows',
#  'then',
#  'ashputtel',
#  'brought',
#  'the',
#  'dish',
#  'to',
#  'her',
#  'mother',
#  'overjoyed',
#  'at',
#  'the',
#  'thought',
#  'that',
#  'now',
#  'she',
#  'should',
#  'go',
#  'to',
#  'the',
#  'ball',
#  'but',
#  'the',
#  'mother',
#  'said',
#  '‘no',
#  'no!',
#  'you',
#  'slut',
#  'you',
#  'have',
#  'no',
#  'clothes',
#  'and',
#  'cannot',
#  'dance;',
#  'you',
#  'shall',
#  'not',
#  'go',
#  '’',
#  'and',
#  'when',
#  'ashputtel',
#  'begged',
#  'very',
#  'hard',
#  'to',
#  'go',
#  'she',
#  'said',
#  '‘if',
#  'you',
#  'can',
#  'in',
#  'one',
#  'hour’s',
#  'time',
#  'pick',
#  'two',
#  'of',
#  'those',
#  'dishes',
#  'of',
#  'peas',
#  'out',
#  'of',
#  'the',
#  'ashes',
#  'you',
#  'shall',
#  'go',
#  'too',
#  '’',
#  'and',
#  'thus',
#  'she',
#  'thought',
#  'she',
#  'should',
#  'at',
#  'least',
#  'get',
#  'rid',
#  'of',
#  'her',
#  'so',
#  'she',
#  'shook',
#  'two',
#  'dishes',
#  'of',
#  'peas',
#  'into',
#  'the',
#  'ashes',
#  'but',
#  'the',
#  'little',
#  'maiden',
#  'went',
#  'out',
#  'into',
#  'the',
#  'garden',
#  'at',
#  'the',
#  'back',
#  'of',
#  'the',
#  'house',
#  'and',
#  'cried',
#  'out',
#  'as',
#  'before:',
#  '‘hither',
#  'hither',
#  'through',
#  'the',
#  'sky',
#  'turtle-doves',
#  'and',
#  'linnets',
#  'fly!',
#  'blackbird',
#  'thrush',
#  'and',
#  'chaffinch',
#  'gay',
#  'hither',
#  'hither',
#  'haste',
#  'away!',
#  'one',
#  'and',
#  'all',
#  'come',
#  'help',
#  'me',
#  'quick!',
#  'haste',
#  'ye',
#  'haste',
#  'ye!--pick',
#  'pick',
#  'pick!’',
#  'then',
#  'first',
#  'came',
#  'two',
#  'white',
#  'doves',
#  'in',
#  'at',
#  'the',
#  'kitchen',
#  'window;',
#  'next',
#  'came',
#  'two',
#  'turtle-doves;',
#  'and',
#  'after',
#  'them',
#  'came',
#  ...]

# %% [markdown]
# # Oversigt over streng-metoder
# Klik på linket og få overblik over de streng-metoder, der er indbygget i Python: https://www.w3schools.com/python/python_strings_methods.asp

# %% [markdown]
# # Lister
# I lister kan du gemme en samling af elementer i en enkelt variabel. Det kan f.eks. være en ordliste, som du gemmer i variablen "word_list".
#
# Lister er kendetegnet ved at de firkantede parenteser. Hvis der er tale om en ordliste kunne den se således ud:
#
# word_list = ['and', 'soon', 'a', 'little', 'bird', 'came']
#
# I ordlisten består hvert element af en tekststreng, som er kendetegnet ved citationstegnene. Hvert element er adskilt af et komma. Listen begynder og ender med firkantene parenteser.
#
# Elementerne  indekseres; det første element har indeks [0], det andet element har indeks [1] osv.
#
# På lister kan du også bruge negativ indeksering. Det vil sige, at tællingen starter fra slutningen.
#
# [-1] er det sidste element og [-2] er det næstsidste element osv.
#
# Du kan også vælge et indexinterval og angive, hvor intervallet starter, og hvor det slutter.
#
# På den måde kan du returnere en afgrænset del af listen.
#
# Hvis du f.eks. vil returnere de første 10 ord fra listen, ser det således ud.

# %%
word_list[0:10]
# Out:
# ['ashputtel', 'the', 'wife', 'of', 'a', 'rich', 'man', 'fell', 'sick;', 'and']

# %% [markdown]
# ## len() functionen og lister
# len() functionen fungerer også sammen med lister og kan returnere antallet af elementer i listen.

# %%
total_words = len(word_list)
print (f'Ordlisten består af {total_words} ord.' )

word = 'bird'
word_count = clean_string.count(word)

res = round((word_count / total_words) * 100, 2)

print (f'Ordet {word} udgør {res} % af hele teksten.')
# Out:
# Ordlisten består af 2587 ord.
# Ordet bird udgør 0.39 % af hele teksten.

# %% [markdown]
# ## Tilføj (append) elementer til liste
#
# Du kan tilføje nye elementer til en liste med append(). De nye elementer bliver tilføjet i slutningen af listen.

# %%
the_end = word_list[-20:]
the_end.append('The End')
the_end
# Out:
# ['dove',
#  'had',
#  'done',
#  'its',
#  'song',
#  'it',
#  'came',
#  'flying',
#  'and',
#  'perched',
#  'upon',
#  'her',
#  'right',
#  'shoulder',
#  'and',
#  'so',
#  'went',
#  'home',
#  'with',
#  'her',
#  'The End']

# %% [markdown]
# ## Oversigt over list metoder
# Klik på linket og få overblik over de list-metoder, der er indbygget i Python:  https://www.w3schools.com/python/python_lists_methods.asp

# %% [markdown]
# # Dictionary to store word counts
# Vi laver en dictionary, som vi bruger til at gemme ordfrekvenser.

# %%
word_dict = {}  # Dictionary to store word counts
    
for word in word_list:
    word_dict[word] = word_dict.get(word, 0) + 1
    
word_dict
# Out:
# {'ashputtel': 14,
#  'the': 182,
#  'wife': 4,
#  'of': 26,
#  'a': 21,
#  'rich': 2,
#  'man': 1,
#  'fell': 2,
#  'sick;': 1,
#  'and': 179,
#  'when': 24,
#  'she': 57,
#  'felt': 1,
#  'that': 25,
#  'her': 92,
#  'end': 2,
#  'drew': 2,
#  'nigh': 1,
#  'called': 3,
#  'only': 3,
#  'daughter': 3,
#  'to': 80,
#  'bed-side': 1,
#  'said': 24,
#  '‘always': 1,
#  'be': 4,
#  'good': 4,
#  'girl': 4,
#  'i': 3,
#  'will': 8,
#  'look': 6,
#  'down': 13,
#  'from': 6,
#  'heaven': 3,
#  'watch': 1,
#  'over': 6,
#  'you': 18,
#  '’': 23,
#  'soon': 4,
#  'afterwards': 1,
#  'shut': 2,
#  'eyes': 1,
#  'died': 1,
#  'was': 24,
#  'buried': 1,
#  'in': 20,
#  'garden;': 1,
#  'little': 15,
#  'went': 14,
#  'every': 2,
#  'day': 6,
#  'grave': 2,
#  'wept': 1,
#  'always': 3,
#  'kind': 2,
#  'all': 20,
#  'about': 3,
#  'snow': 1,
#  'spread': 1,
#  'beautiful': 6,
#  'white': 5,
#  'covering': 1,
#  'grave;': 1,
#  'but': 26,
#  'by': 12,
#  'time': 5,
#  'spring': 1,
#  'came': 24,
#  'sun': 1,
#  'had': 21,
#  'melted': 1,
#  'it': 28,
#  'away': 11,
#  'again': 10,
#  'father': 9,
#  'married': 1,
#  'another': 1,
#  'this': 6,
#  'new': 1,
#  'two': 11,
#  'daughters': 3,
#  'own': 2,
#  'brought': 9,
#  'home': 11,
#  'with': 18,
#  'her;': 3,
#  'they': 23,
#  'were': 9,
#  'fair': 2,
#  'face': 4,
#  'foul': 1,
#  'at': 24,
#  'heart': 1,
#  'now': 5,
#  'sorry': 1,
#  'for': 27,
#  'poor': 1,
#  '‘what': 2,
#  'does': 1,
#  'good-for-nothing': 1,
#  'want': 3,
#  'parlour?’': 1,
#  'they;': 1,
#  '‘they': 1,
#  'who': 7,
#  'would': 4,
#  'eat': 1,
#  'bread': 1,
#  'should': 6,
#  'first': 8,
#  'earn': 1,
#  'it;': 2,
#  'kitchen-maid!’': 1,
#  'then': 25,
#  'took': 10,
#  'fine': 5,
#  'clothes': 8,
#  'gave': 3,
#  'an': 3,
#  'old': 1,
#  'grey': 3,
#  'frock': 4,
#  'put': 10,
#  'on': 17,
#  'laughed': 2,
#  'turned': 4,
#  'into': 21,
#  'kitchen': 4,
#  'there': 5,
#  'forced': 1,
#  'do': 1,
#  'hard': 3,
#  'work;': 1,
#  'rise': 1,
#  'early': 1,
#  'before': 6,
#  'daylight': 1,
#  'bring': 2,
#  'water': 1,
#  'make': 1,
#  'fire': 1,
#  'cook': 1,
#  'wash': 1,
#  'besides': 1,
#  'sisters': 7,
#  'plagued': 1,
#  'sorts': 1,
#  'ways': 1,
#  'evening': 1,
#  'tired': 1,
#  'no': 12,
#  'bed': 1,
#  'lie': 2,
#  'made': 6,
#  'hearth': 1,
#  'among': 4,
#  'ashes;': 3,
#  'as': 14,
#  'course': 1,
#  'dusty': 1,
#  'dirty': 3,
#  'happened': 2,
#  'once': 3,
#  'going': 2,
#  'asked': 5,
#  'his': 15,
#  'wife’s': 1,
#  'what': 4,
#  'he': 26,
#  'them': 9,
#  '‘fine': 1,
#  'first;': 1,
#  '‘pearls': 1,
#  'diamonds': 2,
#  'cried': 5,
#  'second': 1,
#  '‘now': 2,
#  'child': 2,
#  'have?’': 1,
#  '‘the': 2,
#  'twig': 2,
#  'dear': 1,
#  'brushes': 1,
#  'against': 2,
#  'your': 3,
#  'hat': 1,
#  'turn': 1,
#  'come': 3,
#  'homewards': 2,
#  'bought': 1,
#  'pearls': 1,
#  'for:': 1,
#  'way': 2,
#  'rode': 4,
#  'through': 4,
#  'green': 1,
#  'copse': 1,
#  'hazel': 1,
#  'brushed': 1,
#  'him': 10,
#  'almost': 1,
#  'pushed': 1,
#  'off': 7,
#  'hat:': 1,
#  'so': 13,
#  'broke': 1,
#  'away;': 1,
#  'got': 3,
#  'mother’s': 1,
#  'planted': 1,
#  'there;': 1,
#  'much': 4,
#  'watered': 1,
#  'tears;': 1,
#  'grew': 1,
#  'became': 1,
#  'tree': 6,
#  'three': 2,
#  'times': 1,
#  'cried;': 1,
#  'bird': 6,
#  'built': 1,
#  'its': 2,
#  'nest': 1,
#  'upon': 4,
#  'talked': 1,
#  'watched': 1,
#  'whatever': 1,
#  'wished': 1,
#  'king': 2,
#  'land': 1,
#  'held': 2,
#  'feast': 7,
#  'which': 3,
#  'last': 3,
#  'days;': 1,
#  'out': 11,
#  'those': 2,
#  'son': 9,
#  'choose': 1,
#  'bride': 10,
#  'himself': 3,
#  'ashputtel’s': 1,
#  'come;': 2,
#  'up': 4,
#  'comb': 1,
#  'our': 3,
#  'hair': 1,
#  'brush': 1,
#  'shoes': 1,
#  'tie': 1,
#  'sashes': 1,
#  'us': 2,
#  'we': 1,
#  'are': 2,
#  'dance': 5,
#  'king’s': 10,
#  'did': 3,
#  'told;': 1,
#  'done': 4,
#  'could': 5,
#  'not': 16,
#  'help': 3,
#  'crying': 1,
#  'thought': 6,
#  'herself': 4,
#  'have': 8,
#  'liked': 1,
#  'gone': 5,
#  'ball;': 1,
#  'begged': 2,
#  'mother': 12,
#  'very': 2,
#  'let': 2,
#  'go': 14,
#  '‘you': 2,
#  'ashputtel!’': 1,
#  'she;': 1,
#  'nothing': 1,
#  'wear': 2,
#  'cannot': 5,
#  'even': 1,
#  'dance--you': 1,
#  'ball?': 1,
#  'kept': 1,
#  'begging': 1,
#  'get': 2,
#  'rid': 2,
#  '‘i': 4,
#  'throw': 1,
#  'dishful': 1,
#  'peas': 4,
#  'ash-heap': 1,
#  'if': 2,
#  'hours’': 1,
#  'picked': 2,
#  'shall': 4,
#  'too': 7,
#  'threw': 1,
#  'ashes': 8,
#  'maiden': 4,
#  'ran': 2,
#  'back': 9,
#  'door': 3,
#  'garden': 5,
#  'out:': 2,
#  '‘hither': 2,
#  'hither': 6,
#  'sky': 2,
#  'turtle-doves': 2,
#  'linnets': 2,
#  'fly!': 2,
#  'blackbird': 2,
#  'thrush': 2,
#  'chaffinch': 2,
#  'gay': 2,
#  'haste': 6,
#  'away!': 2,
#  'one': 12,
#  'me': 5,
#  'quick!': 2,
#  'ye': 2,
#  'ye!--pick': 2,
#  'pick': 11,
#  'pick!’': 2,
#  'doves': 4,
#  'flying': 2,
#  'window;': 2,
#  'next': 4,
#  'turtle-doves;': 2,
#  'after': 2,
#  'birds': 2,
#  'under': 3,
#  'chirping': 2,
#  'fluttering': 1,
#  'in:': 1,
#  'flew': 5,
#  'stooped': 1,
#  'their': 3,
#  'heads': 2,
#  'set': 4,
#  'work': 3,
#  'pick;': 3,
#  'others': 2,
#  'began': 2,
#  'pick:': 1,
#  'grain': 2,
#  'dish': 2,
#  'left': 6,
#  'long': 1,
#  'hour': 2,
#  'quite': 2,
#  'windows': 1,
#  'overjoyed': 2,
#  'ball': 4,
#  '‘no': 3,
#  'no!': 1,
#  'slut': 1,
#  'dance;': 1,
#  '‘if': 1,
#  'can': 1,
#  'hour’s': 2,
#  'dishes': 4,
#  'thus': 3,
#  'least': 1,
#  'shook': 1,
#  'house': 4,
#  'before:': 1,
#  'hopping': 1,
#  'half': 1,
#  'rejoicing': 1,
#  'think': 2,
#  '‘it': 1,
#  'is': 12,
#  'use': 1,
#  'go;': 1,
#  'shame’:': 1,
#  'nobody': 2,
#  'sorrowfully': 1,
#  'sat': 3,
#  'hazel-tree': 10,
#  '‘shake': 3,
#  'shake': 3,
#  'gold': 4,
#  'silver': 4,
#  'me!’': 3,
#  'friend': 2,
#  'dress': 3,
#  'slippers': 2,
#  'spangled': 1,
#  'silk;': 1,
#  'followed': 3,
#  'know': 1,
#  'must': 2,
#  'some': 1,
#  'strange': 1,
#  'princess': 1,
#  'looked': 4,
#  'clothes;': 1,
#  'never': 2,
#  'taking': 1,
#  'granted': 1,
#  'safe': 1,
#  'dirt': 1,
#  'hand': 2,
#  'danced': 5,
#  'else:': 1,
#  'hand;': 1,
#  'anyone': 3,
#  'else': 2,
#  'ask': 1,
#  '‘this': 6,
#  'lady': 5,
#  'dancing': 2,
#  'till': 4,
#  'late': 1,
#  'night;': 1,
#  'wanted': 5,
#  'home:': 1,
#  'take': 3,
#  'care': 2,
#  'home’;': 1,
#  'see': 2,
#  'where': 4,
#  'lived': 1,
#  'slipped': 4,
#  'unawares': 1,
#  'towards': 1,
#  'home;': 3,
#  'prince': 5,
#  'jumped': 2,
#  'pigeon-house': 3,
#  'waited': 2,
#  'told': 2,
#  'unknown': 2,
#  'been': 2,
#  'hid': 1,
#  'broken': 1,
#  'open': 1,
#  'found': 2,
#  'within;': 1,
#  'lying': 1,
#  'dim': 1,
#  'lamp': 1,
#  'burning': 1,
#  'chimney': 1,
#  'run': 1,
#  'quickly': 1,
#  'taken': 1,
#  'beneath': 1,
#  'might': 2,
#  'carry': 1,
#  'lain': 1,
#  'amid': 1,
#  'said:': 2,
#  'still': 3,
#  'finer': 2,
#  'than': 2,
#  'worn': 1,
#  'everyone': 1,
#  'wondered': 1,
#  'beauty:': 2,
#  'waiting': 1,
#  'night': 2,
#  'here': 2,
#  'went:': 1,
#  'sprang': 1,
#  'behind': 1,
#  'father’s': 1,
#  'stood': 2,
#  'large': 2,
#  'pear-tree': 2,
#  'full': 1,
#  'ripe': 1,
#  'fruit;': 1,
#  'knowing': 1,
#  'hide': 1,
#  'without': 1,
#  'being': 1,
#  'seen': 1,
#  'lost': 1,
#  'sight': 1,
#  'find': 1,
#  'has': 1,
#  'sprung': 1,
#  '‘can': 1,
#  'ashputtel?’': 1,
#  'axe': 1,
#  'brought;': 1,
#  'cut': 3,
#  'lay': 1,
#  'other': 3,
#  'side': 4,
#  'carried': 1,
#  'third': 1,
#  'former': 1,
#  'gold:': 1,
#  'knew': 2,
#  'say': 1,
#  'wonder': 1,
#  '_my_': 1,
#  'partner': 1,
#  'sir': 1,
#  'lose': 1,
#  'time’;': 1,
#  'however': 2,
#  'though': 1,
#  'such': 1,
#  'hurry': 1,
#  'dropped': 1,
#  'golden': 5,
#  'slipper': 6,
#  'stairs': 1,
#  'shoe': 9,
#  'my': 2,
#  'fits': 1,
#  'both': 2,
#  'hear': 1,
#  'feet': 1,
#  'doubt': 1,
#  'eldest': 1,
#  'room': 2,
#  'try': 2,
#  'great': 2,
#  'toe': 2,
#  'altogether': 1,
#  'small': 3,
#  'knife': 1,
#  '‘never': 1,
#  'mind': 1,
#  'off;': 1,
#  'queen': 1,
#  'toes;': 1,
#  'walk': 1,
#  'silly': 1,
#  'squeezed': 2,
#  'beside': 1,
#  'horse': 5,
#  'pass': 1,
#  'planted;': 1,
#  'branch': 1,
#  'dove': 4,
#  'singing:': 1,
#  '‘back': 2,
#  'again!': 4,
#  'shoe!': 3,
#  'you!': 3,
#  'prince!': 6,
#  'thy': 6,
#  'she’s': 2,
#  'true': 4,
#  'sits': 3,
#  'foot;': 1,
#  'saw': 2,
#  'blood': 3,
#  'streamed': 2,
#  'trick': 1,
#  'played': 1,
#  'round': 1,
#  'false': 1,
#  'right': 3,
#  'bride;': 1,
#  'sister': 1,
#  'foot': 2,
#  'heel': 1,
#  'son:': 1,
#  'sang:': 2,
#  'stockings': 1,
#  'red': 1,
#  'also': 1,
#  'father;': 1,
#  '‘have': 1,
#  'daughters?’': 1,
#  'he;': 1,
#  '‘there': 1,
#  'wife;': 1,
#  'am': 1,
#  'sure': 1,
#  'send': 1,
#  'dirty;': 1,
#  'dare': 1,
#  'show': 1,
#  'washed': 1,
#  'hands': 1,
#  'curtsied': 1,
#  'reached': 1,
#  'clumsy': 1,
#  'slipper;': 1,
#  'fitted': 1,
#  'near': 1,
#  'frightened': 1,
#  'pale': 1,
#  'anger': 1,
#  '‘home!': 1,
#  'home!': 1,
#  'princess!': 1,
#  'side!’': 1,
#  'song': 1,
#  'perched': 1,
#  'shoulder': 1}
