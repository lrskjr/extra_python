# %% [markdown]
# Formålet er at opnå et kendskab til regulære udtryk og deres implementering i Python.
#
# RegEx' anvendelse er meget udbredt, fordi RegEx er super smart i relation til tekstbehandling, fordi det kan bruges til at foretage avancerede søgninger. RegEx anvendes til søgemaskiner og til søg og erstat funktioner. At arbejde med RegEx er afgjort en oplevelse for sig, men når man får indblik i omfanget af opgaver, som kan løses med RegEx, så indser man, at det er et utroligt godt værktøj.
#
# Denne notebook forsøger ikke at lære dig alt om RegEx, men den forsøger at skabe læring om det, og kun et fåtal af mulighederne bliver illustreret nedenfor.
#
# Foruden RegEx indeholder denne notebook mange loops, så på den måde kan du også få indblik i, hvordan du skriver den slags.

# %%
# importer biblioteker
import urllib.request
import re
import nltk
import os

# %%
# hent teksten
url = 'https://www.gutenberg.org/files/2591/2591-0.txt'
raw_text = urllib.request.urlopen(url).read().decode()

# %%
#find starten
start = raw_text.find('THE BROTHERS GRIMM FAIRY TALES') + len('THE BROTHERS GRIMM FAIRY TALES')
# find slutningen
end = raw_text.find('*****')
# find det der imellem
content = raw_text[start:end]

#opdel på hvert eventyr 
tales = content.split('\r\n\r\n\r\n\r\n\r\n') # split før overskrift på titel
# Filtrer første item væk, fordi det er tomt
tales = tales[1:] 

titles = []
for i in tales:
    split_text = i.split('\r\n\r\n\r\n') # split efter titel
    title = split_text[0] # gem første del af splittet - det er titlen  
    titles.append(title) # tilføj titlen til den tomme liste

# zip titles og tales    
zip_format = list(zip(titles, tales))

# %%
# lav en ny mappe
#os.mkdir('grimm_tales')
os.chdir('grimm_tales')

# %%
# Gem filerne i mappen
for i in zip_format:
    new_file = open(i[0]+'.txt', 'w', encoding='utf-8-sig')
    new_file.write(i[1])
    new_file.close()

# %% [markdown]
# # Rens teksten
# Rensning af tekst kan foregå på flere måder. Metoden nedenfor er på den måde en ud af flere måder.
#
# Vi begynder med at importere RegEx (import re).
#
# RegEx mønsteret er '\b\S+\b'.
#
# \b : \b finder positionen ved grænsen af et ord (word boundary).
#
# \S: \S matcher ethvert ikke-mellemrum
#
# +: + matcher det forrige tegn mellem én og et ubegrænset antal gange, så mange gange som muligt ind til næste tegn. Man siger, at plusset er grådigt.
#
# \b : \b finder positionen ved grænsen af et ord (word boundary).
#
#
#
# ### Clean the text
# Cleaning text can be done in several ways. The method below is one of several approaches.
#
# We start by importing RegEx (import re).
#
# The RegEx pattern is '\b\S+\b'.
#
# \b : \b finds the position at the boundary of a word (word boundary).
#
# \S: \S matches any non-whitespace character.
#
# : + matches the previous character between one and an unlimited number of times, as many times as possible until the next character. It's said that the plus is greedy.
# \b : \b finds the position at the boundary of a word (word boundary).

# %%
clean_texts = []
for text in tales:
    text_lower_string = text.lower()
    # RexEx funktionen .findall returnerer en liste af ord
    text_clean_list = re.findall(r'\b\S+\b', text_lower_string)
    # Med ' '.join samles ordlisten til en tekststreng
    text = ' '.join(text_clean_list)
    # Med append tilføjes tekststrengen til listen clean_texts
    clean_texts.append(text)

# %%
len(clean_texts)
# Out:
# 62

# %% [markdown]
# # Sammenligninger
# I litteratur anvender man ofte sammenligninger til at illustrere pointer tydeligere ved at sætte billeder på det man vil beskrive. Sammenligninger bidrager også til at gøre teksten mere levende og intererssant.
#
# Men regex bliver det en overkommelig opgave at hente eksempler på sammenligninger i Grimms eventyr, fordi vi kan finde tekststrenge som følger mønsteret i en typisk sammenligning.
#
# Vi kan illustrere det på følgende måde. Vi leder efter fraser, hvis mønster enten er as a ... eller as an ....
#
# RegEx mønsteret kan skrives således:
#
# 'as\sa\s\w+'
#
# Ordet 'as' efterfølges af \s, der betyder white space, der efterfølges af a, derefterføgles af \s, der efterfølges \w, der betyder word charater, der efterfølges af + der betyder "en eller flere af den forrige".
#
#
# #### Comparisons
# In literature, comparisons are often used to illustrate points more clearly by creating mental images of what is being described. Comparisons also make the text more vivid and engaging.
#
# With regex, it becomes a manageable task to extract examples of comparisons in Grimms' fairy tales because we can find text strings that follow the pattern of a typical comparison.
#
# We can illustrate it as follows. We are looking for phrases whose pattern is either "as a ..." or "as an ...".
#
# The RegEx pattern can be written as:
#
# 'as\sa\s\w+'
#
# The word 'as' is followed by \s, which means white space, followed by 'a', then followed by \s, which is followed by \w, meaning a word character, followed by +, which means "one or more of the previous."

# %%
comparisons = []
for text in clean_texts:
    comparison = re.findall(r'as\sa\s\w+', text)
    comparisons.append(comparison)
    
comparisons
# Out:
# [['as a poor'],
#  ['as a countryman'],
#  ['as a beautiful', 'as a stone', 'as a large', 'as a costly'],
#  ['as a musician'],
#  ['as a mouse'],
#  [],
#  ['as a narrow', 'as a golden'],
#  [],
#  ['as a king', 'as a loud', 'as a token'],
#  ['as a parlour',
#   'as a little',
#   'as a courtyard',
#   'as a garden',
#   'as a park',
#   'as a little'],
#  [],
#  ['as a gentle'],
#  ['as a white'],
#  ['as a daughter', 'as a good'],
#  ['as a lovely'],
#  ['as a little'],
#  ['as a chandelier'],
#  ['as a little', 'as a great', 'as a dowry'],
#  ['as a little', 'as a feast'],
#  [],
#  ['as a widow', 'as a little', 'as a thousand'],
#  ['as a dear', 'as a great'],
#  ['as a girl', 'as a mouse', 'as a gold'],
#  ['as a show'],
#  ['as a great'],
#  [],
#  [],
#  ['as a certain', 'as a cow', 'as a storm', 'as a knocking'],
#  ['as a sack', 'as a road'],
#  ['as a real', 'as a magical'],
#  ['as a peasant', 'as a king'],
#  ['as a little', 'as a companion', 'as a strange', 'as a flower'],
#  ['as a jingling'],
#  ['as a sad', 'as a great'],
#  [],
#  ['as a great'],
#  ['as a soft'],
#  ['as a little', 'as a wicket'],
#  [],
#  ['as a court', 'as a boy', 'as a burning', 'as a roaring'],
#  ['as a mark'],
#  [],
#  ['as a token', 'as a son'],
#  [],
#  ['as a great', 'as a reward'],
#  ['as a garden', 'as a crack', 'as a feast'],
#  [],
#  ['as a few'],
#  [],
#  ['as a man', 'as a fine', 'as a goose'],
#  [],
#  ['as a remembrance', 'as a wondrous'],
#  ['as a sword', 'as a fly'],
#  ['as a cock'],
#  [],
#  ['as a young', 'as a suitor', 'as a little'],
#  ['as a merry', 'as a large', 'as a witch', 'as a bird'],
#  ['as a certain', 'as a ghost', 'as a roaring'],
#  ['as a tub'],
#  ['as a white'],
#  [],
#  ['as a garden',
#   'as a pleasure',
#   'as a rose',
#   'as a poor',
#   'as a bear',
#   'as a savage']]

# %% [markdown]
# En liste med en zip funktion, der samler filnavne og sammenligninger giver en liste, så vi kan se eventyr og sammenligninger sammen.
#
# A list with a zip function that combines file names and comparisons provides a list.

# %%
list(zip(titles,comparisons))
# Out:
# [('THE GOLDEN BIRD', ['as a poor']),
#  ('HANS IN LUCK', ['as a countryman']),
#  ('JORINDA AND JORINDEL',
#   ['as a beautiful', 'as a stone', 'as a large', 'as a costly']),
#  ('THE TRAVELLING MUSICIANS', ['as a musician']),
#  ('OLD SULTAN', ['as a mouse']),
#  ('THE STRAW, THE COAL, AND THE BEAN', []),
#  ('BRIAR ROSE', ['as a narrow', 'as a golden']),
#  ('THE DOG AND THE SPARROW', []),
#  ('THE TWELVE DANCING PRINCESSES', ['as a king', 'as a loud', 'as a token']),
#  ('THE FISHERMAN AND HIS WIFE',
#   ['as a parlour',
#    'as a little',
#    'as a courtyard',
#    'as a garden',
#    'as a park',
#    'as a little']),
#  ('THE WILLOW-WREN AND THE BEAR', []),
#  ('THE FROG-PRINCE', ['as a gentle']),
#  ('CAT AND MOUSE IN PARTNERSHIP', ['as a white']),
#  ('THE GOOSE-GIRL', ['as a daughter', 'as a good']),
#  ('THE ADVENTURES OF CHANTICLEER AND PARTLET', ['as a lovely']),
#  ('RAPUNZEL', ['as a little']),
#  ('FUNDEVOGEL', ['as a chandelier']),
#  ('THE VALIANT LITTLE TAILOR', ['as a little', 'as a great', 'as a dowry']),
#  ('HANSEL AND GRETEL', ['as a little', 'as a feast']),
#  ('THE MOUSE, THE BIRD, AND THE SAUSAGE', []),
#  ('MOTHER HOLLE', ['as a widow', 'as a little', 'as a thousand']),
#  ('LITTLE RED-CAP [LITTLE RED RIDING HOOD]', ['as a dear', 'as a great']),
#  ('THE ROBBER BRIDEGROOM', ['as a girl', 'as a mouse', 'as a gold']),
#  ('TOM THUMB', ['as a show']),
#  ('RUMPELSTILTSKIN', ['as a great']),
#  ('CLEVER GRETEL', []),
#  ('THE OLD MAN AND HIS GRANDSON', []),
#  ('THE LITTLE PEASANT',
#   ['as a certain', 'as a cow', 'as a storm', 'as a knocking']),
#  ('FREDERICK AND CATHERINE', ['as a sack', 'as a road']),
#  ('SWEETHEART ROLAND', ['as a real', 'as a magical']),
#  ('SNOWDROP', ['as a peasant', 'as a king']),
#  ('THE PINK',
#   ['as a little', 'as a companion', 'as a strange', 'as a flower']),
#  ('CLEVER ELSIE', ['as a jingling']),
#  ('THE MISER IN THE BUSH', ['as a sad', 'as a great']),
#  ('ASHPUTTEL', []),
#  ('THE WHITE SNAKE', ['as a great']),
#  ('THE WOLF AND THE SEVEN LITTLE KIDS', ['as a soft']),
#  ('THE QUEEN BEE', ['as a little', 'as a wicket']),
#  ('THE ELVES AND THE SHOEMAKER', []),
#  ('THE JUNIPER-TREE',
#   ['as a court', 'as a boy', 'as a burning', 'as a roaring']),
#  ('THE TURNIP', ['as a mark']),
#  ('CLEVER HANS', []),
#  ('THE THREE LANGUAGES', ['as a token', 'as a son']),
#  ('THE FOX AND THE CAT', []),
#  ('THE FOUR CLEVER BROTHERS', ['as a great', 'as a reward']),
#  ('LILY AND THE LION', ['as a garden', 'as a crack', 'as a feast']),
#  ('THE FOX AND THE HORSE', []),
#  ('THE BLUE LIGHT', ['as a few']),
#  ('THE RAVEN', []),
#  ('THE GOLDEN GOOSE', ['as a man', 'as a fine', 'as a goose']),
#  ('THE WATER OF LIFE', []),
#  ('THE TWELVE HUNTSMEN', ['as a remembrance', 'as a wondrous']),
#  ('THE KING OF THE GOLDEN MOUNTAIN', ['as a sword', 'as a fly']),
#  ('DOCTOR KNOWALL', ['as a cock']),
#  ('THE SEVEN RAVENS', []),
#  ('THE WEDDING OF MRS FOX', ['as a young', 'as a suitor', 'as a little']),
#  ('THE SALAD', ['as a merry', 'as a large', 'as a witch', 'as a bird']),
#  ('THE STORY OF THE YOUTH WHO WENT FORTH TO LEARN WHAT FEAR WAS',
#   ['as a certain', 'as a ghost', 'as a roaring']),
#  ('KING GRISLY-BEARD', ['as a tub']),
#  ('IRON HANS', ['as a white']),
#  ('CAT-SKIN', []),
#  ('SNOW-WHITE AND ROSE-RED',
#   ['as a garden',
#    'as a pleasure',
#    'as a rose',
#    'as a poor',
#    'as a bear',
#    'as a savage'])]

# %% [markdown]
# # Find et tekstuddrag baseret på søgeord og et interval
# Vi vil finde ordet 'king' samt ord, der er beslægtet med ordet, og vi må have noget kontekst med, fordi vi er faktisk interesseret i at pege ned i teksten og se, hvordan konge helt præcist bliver brugt.
#
# Til dette skal vi bruge \w., fordi det giver os flere ordtegn og {30} søger for, at vi får 30 ordtegn før, vi rammer bogstaverne king. \b foran king søger for at vi kun finder ord, der begynder med king og ikke ord, hvor king er en del af ordet, f.eks. looking. Efter king søger \w.{30} for, at vi får endnu 30 ordtegn.
#
#
#
# ### Find a text excerpt based on keywords and an interval
# We want to find the word 'king' as well as words related to it, and we need some context because we are actually interested in diving into the text and seeing how 'king' is used precisely.
#
# For this, we need to use \w., as it gives us multiple word characters, and {30} ensures that we get 30 word characters before we hit the letters 'king'. \b in front of 'king' ensures that we only find words that begin with 'king' and not words where 'king' is part of the word, such as 'looking'. After 'king', \w.{30} ensures that we get another 30 word characters.

# %%
#clean_texts[20]

# %%
re.findall(r'.{0,30}\btime.{0,30}', clean_texts[20])
# Out:
# ['mother holle once upon a time there was a widow who had two',
#  'old woman’s bidding and every time she made the bed she shook it',
#  'on with mother holle for some time and then she began to grow un',
#  'k although she was a thousand times better off with mother holle']

# %% [markdown]
# Læg regex mønsteret i et loop og få overblikket over, hvordan ordet benyttes.

# %%
contexts1 = []
for text in clean_texts:
    context = re.findall(r'.{0,30}\bking.{0,30}', text) # ig 
    contexts1.append(context)

list(zip(titles,contexts1))
# Out:
# [('THE GOLDEN BIRD',
#   ['the golden bird a certain king had a beautiful garden and in',
#    'ight one of them was gone the king became very angry at this and',
#    'en feather was brought to the king in the morning and all the co',
#    're than all the wealth of the kingdom but the king said one feat',
#    'er and carried him before the king the next morning the court sa',
#    'ie unless he should bring the king the golden horse which could ',
#    'hen he was brought before the king and the king said you shall n',
#    'one so he went merrily to the king and told him that now that it',
#    'ive him the princess then the king was obliged to keep his word ',
#    ' be done when you come to the king and he asks for the beautiful',
#    'will ride in and speak to the king and when he sees that it is t',
#    'the bird and went home to the king their master and said all thi',
#    'l you if they find you in the kingdom so he dressed himself as a',
#    ' man and came secretly to the king’s court and was scarcely with',
#    'f weeping then he went to the king and told him all his brothers',
#    'en to him again and after the king’s death he was heir to his ki']),
#  ('HANS IN LUCK', []),
#  ('JORINDA AND JORINDEL', []),
#  ('THE TRAVELLING MUSICIANS', []),
#  ('OLD SULTAN', []),
#  ('THE STRAW, THE COAL, AND THE BEAN', []),
#  ('BRIAR ROSE',
#   ['briar rose a king and queen once upon a time re',
#    'n those days fairies now this king and queen had plenty of money',
#    'rl so very beautiful that the king could not cease looking on it',
#    ' were thirteen fairies in the kingdom but as the king and queen ',
#    'as very angry and scolded the king and queen very much and set t',
#    ' revenge so she cried out the king’s daughter shall in her fifte',
#    'hief so her gift was that the king’s daughter when the spindle w',
#    'r a hundred years however the king hoped still to save his dear ',
#    ' that all the spindles in the kingdom should be bought up and bu',
#    'she was fifteen years old the king and queen were not at home an',
#    'len into a deep sleep and the king and the queen who had just co',
#    ' with a goose upon it for the king’s dinner stood still and the ',
#    'leeping briar rose for so the king’s daughter was called so that',
#    ' from time to time several kings sons came and tried to break',
#    ' many many years there came a king’s son into that land and an o',
#    'ent out together and soon the king and queen also awoke and all ',
#    'e spit with the goose for the king’s dinner upon it the butler f']),
#  ('THE DOG AND THE SPARROW', []),
#  ('THE TWELVE DANCING PRINCESSES',
#   ['ancing princesses there was a king who had twelve beautiful daug',
#    ' where they had been then the king made it known to all the land',
#    'st for his wife and should be king after his death but whoever t',
#    'ghts should be put to death a king’s son soon came he was well e',
#    'chamber was left open but the king’s son soon fell asleep and wh',
#    'second and third night so the king ordered his head to be cut of',
#    'hrough the country where this king reigned and as he was travell',
#    'and then in time i might be a king well said the old dame that i',
#    'ry his luck so he went to the king and said he was willing to un',
#    's the others had been and the king ordered fine royal robes to b',
#    'd have you forgotten how many kings sons have already watched in',
#    'ecret he was taken before the king with the three branches and t',
#    'hat he would say and when the king asked him where do my twelve ',
#    'r ground and then he told the king all that had happened and sho',
#    'had brought with him then the king called for the princesses and',
#    'they confessed it all and the king asked the soldier which of th',
#    ' soldier was chosen to be the king’s heir']),
#  ('THE FISHERMAN AND HIS WIFE',
#   ['estir yourself for we must be king of all the land wife wife sai',
#    ' why should we wish to be the king i will not be king then i wil',
#    ' the fisherman how can you be king--the fish cannot make you a k',
#    't it but go and try i will be king so the man went away quite so',
#    'at his wife should want to be king this time the sea looked a da',
#    ' poor man my wife wants to be king go home said the fish she is ',
#    'king already then the fisherman we',
#    'fe said the fisherman are you king yes said she i am king and wh',
#    'what a fine thing it is to be king now we shall never have anyth',
#    'she never is a long time i am king it is true but i begin to be ',
#    'ask him for such a thing i am king said ilsabill and you are my ']),
#  ('THE WILLOW-WREN AND THE BEAR',
#   ['hat sings so well that is the king of birds said the wolf before',
#    'food in her beak and the lord king came too and they began to fe',
#    'd passed went to it again the king and queen had just flown out ',
#    'etched palace and you are not king’s children you are disreputab',
#    ' has insulted us then the old king said be easy he shall be puni',
#    's had won the battle then the king and queen flew home to their ']),
#  ('THE FROG-PRINCE',
#   ['uld came back to her seat the king her father seeing that someth',
#    ' the greenwood shade then the king said to the young princess as',
#    'd go with me into my father’s kingdom where i will marry you and',
#    't they then took leave of the king and got into the coach with e',
#    'nd merriment for the prince’s kingdom which they reached safely ']),
#  ('CAT AND MOUSE IN PARTNERSHIP', []),
#  ('THE GOOSE-GIRL',
#   ['the goose-girl the king of a great land died and left',
#    'r journey to her bridegroom’s kingdom one day as they were ridin',
#    'n the court below now the old king happened just then to have no',
#    't she may not be idle the old king could not for some time think',
#    'e was to help in watching the king’s geese was curdken but the f',
#    ' home curdken went to the old king and said i cannot have that s',
#    'geese any longer why said the king because instead of doing any ',
#    'ease me all day long then the king made him tell him what had ha',
#    'd curdken went on telling the king what had happened upon the me',
#    'ese to themselves but the old king told the boy to go out again ',
#    'ing her hair all this the old king saw so he went home without b',
#    'hall lose my life but the old king begged so hard that she had n',
#    ' so for when she had done the king ordered royal clothes to be p',
#    ' bride stood by and the young king rejoiced when he saw her beau',
#    'ything to the false bride the king ordered a great feast to be g',
#    'k and were very merry the old king said he would tell them a tal',
#    'ead thou art she said the old king and as thou has judged thysel',
#    'be done to thee and the young king was then married to his true ',
#    'ife and they reigned over the kingdom in peace and happiness all']),
#  ('THE ADVENTURES OF CHANTICLEER AND PARTLET', []),
#  ('RAPUNZEL',
#   [' two it came to pass that the king’s son rode through the forest',
#    'g her sweet voice resound the king’s son wanted to climb up to h',
#    'ly the hair fell down and the king’s son climbed up at first rap',
#    'et beheld came to her but the king’s son began to talk to her qu',
#    ' me to draw up than the young king’s son--he is with me in a mom',
#    'ok of the window and when the king’s son came and cried rapunzel',
#    ' me she let the hair down the king’s son ascended but instead of',
#    ' will never see her again the king’s son was beside himself with',
#    'm as before he led her to his kingdom where he was joyfully rece']),
#  ('FUNDEVOGEL', []),
#  ('THE VALIANT LITTLE TAILOR',
#   ['went and announced him to the king and gave it as their opinion ',
#    'epart the counsel pleased the king and he sent one of his courti',
#    'plied i am ready to enter the king’s service he was therefore ho',
#    'k themselves in a body to the king and begged for their dismissa',
#    'kills seven at one stroke the king was sorry that for the sake o',
#    'ghter to wife and half of his kingdom as a dowry likewise one hu',
#    'beautiful princess and half a kingdom every day of one’s life oh',
#    'little tailor demanded of the king the promised reward he howeve',
#    'y daughter and the half of my kingdom said he to him you must pe',
#    'beast away and took it to the king the king still would not give',
#    ' the hero however went to the king who was now whether he liked ',
#    ' daughter and the half of his kingdom had he known that it was n',
#    'all joy and out of a tailor a king was made after some time the ',
#    'nothing else but a tailor the king comforted her and said leave ',
#    's satisfied with this but the king’s armour-bearer who had heard',
#    'tle tailor was and remained a king to the end of his life']),
#  ('HANSEL AND GRETEL', []),
#  ('THE MOUSE, THE BIRD, AND THE SAUSAGE', []),
#  ('MOTHER HOLLE', []),
#  ('LITTLE RED-CAP [LITTLE RED RIDING HOOD]', []),
#  ('THE ROBBER BRIDEGROOM', []),
#  ('TOM THUMB', []),
#  ('RUMPELSTILTSKIN',
#   [' her that he one day told the king of the land who used to come ',
#    'in gold out of straw now this king was very fond of money and wh',
#    's all spun into gold when the king came and saw this he was grea',
#    'orning all was done again the king was greatly delighted to see ',
#    'e spun the heap into gold the king came in the morning and findi',
#    'ive him all the wealth of the kingdom if he would let her off bu']),
#  ('CLEVER GRETEL', []),
#  ('THE OLD MAN AND HIS GRANDSON', []),
#  ('THE LITTLE PEASANT', []),
#  ('FREDERICK AND CATHERINE', []),
#  ('SWEETHEART ROLAND', []),
#  ('SNOWDROP',
#   ['p but this queen died and the king soon married another wife who',
#    'r name was and that she was a king’s daughter and the coffin was']),
#  ('THE PINK',
#   [' he have then she went to the king and told him the joyful tidin',
#    'e gave birth to a son and the king was filled with gladness ever',
#    'o suckle it and he ran to the king and accused the queen of havi',
#    'r by the wild beasts when the king saw the blood on her apron he',
#    ' girl as a companion then the king’s son wished for one and she ',
#    'urred to him however that the king’s son might some day wish to ',
#    'ched the plate to him but the king’s son threw off the quilt and',
#    'oke forth from his throat the king’s son remained there a short ',
#    'e could offer him service the king said yes if he was skilful an',
#    ' carts and driven home to the king and for once he was able to d',
#    'none at all for years now the king felt great joy at this and co',
#    'all sit by me he replied lord king your majesty must excuse me i',
#    ' am a poor huntsman but the king insisted on it and said you s',
#    'er and wished that one of the king’s principal servants would be',
#    'alive or has she died but the king replied she let my dear son b',
#    'n this the huntsman asked the king if he would like to see the d',
#    'is knife by his side when the king saw him he fell into a passio',
#    'r own life depended on it the king replied yes i would like to s',
#    ' it was so beautiful that the king had never seen one to equal i',
#    'made her look more so and the king sent two waiting-maids and tw',
#    'mselves on her grave the aged king ordered the cook to be torn i',
#    'pieces but grief consumed the king’s own heart and he soon died ']),
#  ('CLEVER ELSIE', []),
#  ('THE MISER IN THE BUSH', []),
#  ('ASHPUTTEL',
#   [' for now it happened that the king of that land held a feast whi',
#    ' we are going to dance at the king’s feast then she did as she w',
#    ' safe at home in the dirt the king’s son soon came up to her and',
#    'she wanted to go home and the king’s son said i shall go and tak',
#    'ondered at her beauty but the king’s son who was waiting for her',
#    'she wanted to go home and the king’s son followed here as before',
#    't without being seen then the king’s son lost sight of her and c',
#    ' wonder at her beauty and the king’s son danced with nobody but ',
#    'she wanted to go home and the king’s son would go with her and s',
#    ' and went the next day to the king his father and said i will ta',
#    'd on the shoe and went to the king’s son then he took her for hi',
#    'lood came and took her to the king’s son and he set her as his b']),
#  ('THE WHITE SNAKE',
#   ['a long time ago there lived a king who was famed for his wisdom ',
#    'ither did anyone know for the king never took off the cover to e',
#    ' allowed to go everywhere the king ordered the man to be brought',
#    'y prove his innocence and the king to make amends for the wrong ',
#    ' he listened and heard an ant-king complain why cannot folks wit',
#    'on to a side path and the ant-king cried out to him we will reme',
#    'on horseback crying aloud the king’s daughter wants a husband bu',
#    'heless when the youth saw the king’s daughter he was so overcome',
#    'ot all danger went before the king and declared himself a suitor',
#    'o it before his eyes then the king ordered him to fetch this rin',
#    'full of joy he took it to the king and expected that he would gr',
#    'gle grain was missing the ant-king had come in the night with th',
#    ' into the sacks presently the king’s daughter herself came down ',
#    'he had wandered through three kingdoms he came one evening to a ',
#    ' took the golden apple to the king’s beautiful daughter who had ']),
#  ('THE WOLF AND THE SEVEN LITTLE KIDS', []),
#  ('THE QUEEN BEE',
#   ['the queen bee two kings sons once upon a time went i',
#    'usand pearls belonging to the king’s daughter they must all be f',
#    'cried and as he sat there the king of the ants whose life he had',
#    ' youngest and the best of the king’s three daughters now they we',
#    'est of the princesses and was king after her father’s death but ']),
#  ('THE ELVES AND THE SHOEMAKER', []),
#  ('THE JUNIPER-TREE', []),
#  ('THE TURNIP',
#   ['o carry it and give it to the king as a mark of respect then he ',
#    ' the court and gave it to the king what a wonderful thing said t',
#    'he king i have seen many strange thin',
#    'poor everybody forgets me the king then took pity on him and sai',
#    ' gold and fine horses for the king and thought he must have a mu',
#    'must his present be worth the king took the gift very graciously']),
#  ('CLEVER HANS', []),
#  ('THE THREE LANGUAGES', []),
#  ('THE FOX AND THE CAT', []),
#  ('THE FOUR CLEVER BROTHERS',
#   ['bustle in the country for the king’s daughter had been carried o',
#    'ff by a mighty dragon and the king mourned over his loss day and',
#    'rding her then he went to the king and asked for a ship for hims',
#    'herefore she is mine then the king put in a word and said each o',
#    'a reward for his skill half a kingdom so the brothers agreed tha',
#    ' no mind to have them and the king then gave to each half a king']),
#  ('LILY AND THE LION', []),
#  ('THE FOX AND THE HORSE', []),
#  ('THE BLUE LIGHT',
#   ['for many years had served the king faithfully but when the war c',
#    'nds which he had received the king said to him you may return to',
#    'in and said i have served the king faithfully but he has dismiss',
#    'le man late at night when the king’s daughter is in bed bring he',
#    'm may have been true said the king i will give you a piece of ad',
#    'the streets but unseen by the king the manikin was standing besi',
#    'il cock-crow next morning the king sent his people out to seek t',
#    'nk of something else said the king keep your shoes on when you g',
#    'nder the bed next morning the king had the entire town searched ',
#    'e begged a last favour of the king what is it asked the king tha',
#    ' may smoke three answered the king but do not imagine that i wil',
#    's constable and spare not the king who has treated me so ill the',
#    'not venture to stir again the king was terrified he threw himsel',
#    'd to live at all gave him his kingdom for his own and his daught']),
#  ('THE RAVEN',
#   ['he raven said i am by birth a king’s daughter but am now under t',
#    'ap in the garden to await the king’s daughter but he felt even m',
#    'year and every day he saw the king’s daughter driving round her ']),
#  ('THE GOLDEN GOOSE',
#   ['rds he came to a city where a king ruled who had a daughter who ',
#    ' and all her train before the king’s daughter and as soon as she',
#    'have her for his wife but the king did not like the son-in-law a',
#    'satisfied he led him into the king’s cellar and the man bent ove',
#    'ce more for his bride but the king was vexed that such an ugly f',
#    'urself full he led him to the king’s palace where all the flour ',
#    'in the whole kingdom was collected and from it ',
#    'e asked for his bride but the king again sought a way out and or',
#    'n land and water and when the king saw that he could no longer p',
#    ' was celebrated and after the king’s death dummling inherited hi',
#    's kingdom and lived for a long time ']),
#  ('THE WATER OF LIFE',
#   ['n a country a great way off a king who had three sons this king ',
#    'nd it and he went to the sick king and begged that he might go i',
#    'at could save him no said the king i had rather die than place y',
#    'ut he begged so hard that the king let him go and the prince tho',
#    'will make me sole heir to his kingdom then he set out and when h',
#    'e spellbound meantime the old king was lingering on in daily hop',
#    'rother is surely dead and the kingdom will fall to me if i find ',
#    'the water the king was at first very unwilling t',
#    ' the spell that bound her the kingdom should be his if he would ',
#    'marry him and to give him the kingdom then they all three rode o',
#    ' want but the prince gave the king of the land the bread and all',
#    ' his kingdom ate of it and he lent the ',
#    'king the wonderful sword and he sl',
#    'y’s army with it and thus the kingdom was once more in peace and',
#    'l forsake us and give him the kingdom which is our right so they',
#    'n brought his cup to the sick king that he might drink and be he',
#    'd we will let you off the old king was still very angry with his',
#    'oing on till one day when the king’s chief huntsmen went a-hunti',
#    'ou alas said the huntsman the king has ordered me to shoot you t',
#    'and embassies came to the old king’s court with rich gifts of go',
#    'hese were sent from the three kings to whom he had lent his swor',
#    'r people this touched the old king’s heart and he thought his so',
#    'me his royal coat at this the king was overwhelmed with joy and ',
#    'e it known throughout all his kingdom that if his son would come',
#    'have her for his wife and the kingdom with her as he came before',
#    'e her husband and lord of the kingdom when the first joy at thei',
#    'ove of his father and the old king was very angry and wanted to ',
#    ' nobody cared and now the old king gathered together his court a',
#    'nd asked all his kingdom to come and celebrate the ']),
#  ('THE TWELVE HUNTSMEN',
#   ['lve huntsmen there was once a king’s son who had a bride whom he',
#    'a remembrance of me when i am king i will return and fetch you s',
#    'i wish and he named a certain king’s daughter who was to be his ',
#    'all be done and thereupon the king shut his eyes and died when t',
#    'e the son had been proclaimed king and the time of mourning was ',
#    'ven his father and caused the king’s daughter to be asked in mar',
#    'earch to be made in his whole kingdom until eleven young maidens',
#    'nd size when they came to the king’s daughter she had twelve sui',
#    ' of them into his service the king looked at her and did not kno',
#    'ke them and now they were the king’s twelve huntsmen the king ho',
#    'at one evening he said to the king you think you have twelve hun',
#    'tsmen yes said the king they are twelve huntsmen the ',
#    'ken they are twelve girls the king said that cannot be true how ',
#    't and the peas roll about the king was well pleased with the cou',
#    ' was however a servant of the king’s who favoured the huntsmen a',
#    'id the lion wants to make the king believe that you are girls th',
#    'en the king’s daughter thanked him and sa',
#    'peas so next morning when the king had the twelve huntsmen calle',
#    ' they went away again and the king said to the lion you have lie',
#    't is what no man would do the king liked the advice and had the ',
#    't so when they were alone the king’s daughter said to her eleven',
#    'els and next morning when the king had his twelve huntsmen summo',
#    ' the spinning-wheels then the king again said to the lion you ha',
#    'ave restrained themselves the king however would no longer belie',
#    ' huntsmen always followed the king to the chase and his liking f',
#    'ut hunting news came that the king’s bride was approaching when ',
#    'll fainting to the ground the king thought something had happene',
#    'ated her to return to her own kingdom for he had a wife already ']),
#  ('THE KING OF THE GOLDEN MOUNTAIN',
#   ['the king of the golden mountain there ',
#    'celebrated and he was crowned king of the golden mountain they l',
#    'sed over their heads when the king thought of his father and he ',
#    ' give him anything to eat the king however still vowed that he w',
#    ' he next told them how he was king of the golden mountain and wa',
#    'ver be true he must be a fine king truly who travels about in a ',
#    ' and her son at home in their kingdom and when he awoke he found',
#    'world till i come again to my kingdom so saying he set out and t',
#    ' that he was come back to the kingdom but the princes peers and ',
#    ' him and heinel was once more king of the golden mountain']),
#  ('DOCTOR KNOWALL', []),
#  ('THE SEVEN RAVENS', []),
#  ('THE WEDDING OF MRS FOX', []),
#  ('THE SALAD',
#   ['id he a messenger sent by the king to find the finest salad that']),
#  ('THE STORY OF THE YOUTH WHO WENT FORTH TO LEARN WHAT FEAR WAS',
#   ['ch in it for three nights the king had promised that he who woul',
#    'outh went next morning to the king and said if it be allowed i w',
#    'hts in the haunted castle the king looked at him and as the yout',
#    'ting-board with the knife the king had these things carried into',
#    'it was day in the morning the king came and when he saw him lyin',
#    'not come to that yet then the king was astonished but very glad ',
#    ' fell asleep next morning the king came to inquire after him how',
#    'or the poor the other for the king the third yours in the meanti',
#    ' by his fire next morning the king came and said now you must ha',
#    ' was to shudder then said the king you have saved the castle and',
#    ' but howsoever much the young king loved his wife and however ha',
#    'o her at night when the young king was sleeping his wife was to ']),
#  ('KING GRISLY-BEARD',
#   ['king grisly-beard a great king of a land far away in the eas',
#    ' of them once upon a time the king held a great feast and asked ',
#    'nged according to their rank--kings and princes and dukes and ea',
#    'ughed more than all at a good king who was there look at him sai',
#    'be called grisly-beard so the king got the nickname of grisly-be',
#    'ard but the old king was very angry when he saw ho',
#    'dow and beg alms and when the king heard him he said let him com',
#    'd when he had sung before the king and the princess he begged a ',
#    'boon then the king said you have sung so well th',
#    'ess begged and prayed but the king said i have sworn to give you',
#    'iddler when this was over the king said now get ready to go--you',
#    'se is this wood it belongs to king grisly-beard answered he hads',
#    ' she would that i had married king grisly-beard next they came t',
#    'adows said she they belong to king grisly-beard hadst thou taken',
#    ' she would that i had married king grisly-beard then they came t',
#    'e city said she it belongs to king grisly-beard hadst thou taken',
#    'ighed she why did i not marry king grisly-beard that is no busin',
#    'of work so i have been to the king’s palace and asked if they di',
#    'ong before she heard that the king’s eldest son was passing by g',
#    'she was going out in came the king’s son in golden clothes and w',
#    ' fear for she saw that it was king grisly-beard who was making s',
#    ' to run away but on the steps king grisly-beard overtook her and']),
#  ('IRON HANS',
#   [' there was once upon a time a king who had a great forest near h',
#    'ent has befallen him said the king and the next day he sent out ',
#    'sman announced himself to the king as seeking a situation and of',
#    'into the dangerous forest the king however would not give his co',
#    'ishment over the wild man the king however had him put in an iro',
#    'to the forest with safety the king had a son of eight years who ',
#    'he boy i will not do that the king has forbidden it and ran away',
#    'ould not on the third day the king had ridden out hunting and th',
#    'teps into the forest when the king came home he observed the emp',
#    'e boy but no one answered the king sent out people to seek for h',
#    ' silver in abundance then the king’s son left the forest and wal',
#    ' had never yet come under the king’s notice and he said when you',
#    'ore place on my head then the king had the cook called before hi',
#    ' fell into the bedroom of the king’s daughter and up she sprang ',
#    'and said how can you take the king’s daughter a garland of such ',
#    'when he got into the room the king’s daughter said take your cap',
#    'th them the following day the king’s daughter again called to hi',
#    'ountry was overrun by war the king gathered together his people ',
#    'ttlefield a great part of the king’s men had already fallen and ',
#    't instead of returning to the king however he conducted his troo',
#    's three-legged horse when the king returned to his palace his da',
#    'he strange knight was but the king did not know and said he foll',
#    ' was still more ridiculed the king said to his daughter i will p',
#    'asked he that i may catch the king’s daughter’s golden apple it ',
#    ' was recognized by no one the king’s daughter came forward and t',
#    ' but galloped off with it the king grew angry and said that is n',
#    'he was riding off with it the king’s attendants pursued him and ',
#    'ack and announced this to the king the following day the king’s ',
#    'n apples which he has won the king had him summoned into his pre',
#    'ittle cap on his head but the king’s daughter went up to him and',
#    'three golden apples asked the king yes answered he and here the ',
#    'cket and returned them to the king if you desire further proof y',
#    ' father my father is a mighty king and gold have i in plenty as ',
#    'i require i well see said the king that i owe my thanks to you c',
#    'he doors opened and a stately king came in with a great retinue ']),
#  ('CAT-SKIN',
#   ['cat-skin there was once a king whose queen had hair of the p',
#    ' end drew near she called the king to her and said promise me th',
#    ' hair like mine then when the king in his grief promised all she',
#    'hut her eyes and died but the king was not to be comforted and f',
#    'men said this will not do the king must marry again that we may ',
#    'r trouble for nothing now the king had a daughter who was just a',
#    'and when she was grown up the king looked at her and saw that sh',
#    'as also shocked but hoped the king would soon give up such thoug',
#    'r to which every beast in the kingdom must give a part of his sk',
#    'of the matter no more but the king made the most skilful workmen',
#    ' in his kingdom weave the three dresses on',
#    'unt out all the beasts in his kingdom and to take the finest fur',
#    ' made when all were ready the king sent them to her but she got ',
#    'till it was midday now as the king to whom the wood belonged was',
#    ' and bark look sharp said the king to the huntsmen and see what ',
#    'lies fast asleep see said the king if you can catch it alive and',
#    'oach and took her home to the king’s palace then they showed her',
#    'a feast was to be held in the king’s castle so she said to the c',
#    't she could be no less than a king’s daughter but the king came ',
#    'end she curtsied and when the king looked round for her she was ',
#    'till the morning and heat the king’s soup i should like to run u',
#    'went away cat-skin heated the king’s soup and toasted a slice of',
#    's when the dance was over the king ordered his soup to be brough',
#    'ating then he went before the king and he asked him who had cook',
#    'did answered the cook but the king said that is not true it was ',
#    'let cat-skin come up said the king and when she came he said to ',
#    'hat was in the soup asked the king then she would not own that s',
#    'nything about the ring so the king sent her away again about her',
#    ' in half an hour and cook the king the soup that he likes so muc',
#    'en she went in looking like a king’s daughter the king went up t',
#    'to slip out so slyly that the king did not see where she was gon',
#    'up then it was brought to the king who ate it and it pleased him',
#    ' was brought again before the king but she still told him that s',
#    'rown at her head but when the king had ordered a feast to be got',
#    'r soup so that it pleases the king better than mine however he l',
#    'o the ball-room in it and the king danced with her again and tho',
#    'to the kitchen and cooked the king’s soup and as soon as the coo',
#    'brooch into the dish when the king got to the bottom he ordered ',
#    'the face of the earth but the king said you are my beloved bride']),
#  ('SNOW-WHITE AND ROSE-RED',
#   ['an clothed all in gold i am a king’s son he said and i was bewit'])]

# %% [markdown]
# # Skattejagt efter egenavne
# Find de ord, der begynder med store bogstaver, men ikke findes med små bogstaver.
#
# Mange af disse ord er skrevet med stort, fordi de optræder efter et punktum, og på den måde er de ikke, hvad jeg vil kalde for "ægte" ord med stort.
#
# Hvis man vil bortfiltrere de "uægte" ord fra sin liste, så kan man afsløre dem ved at lave et loop og indsætte en betingelse, der kan tjekke om, ordene skulle være skrevet med småt andre steder i teksterne, fordi hvis de er det, så er de "uægte".
#
# Konkret gør vi det på den måde at vi looper listen med ord med store bogtaver. Hvis ordet, som vi med .lower() manipulere til kun at bestå af små bogstaver, ikke findes skrevet med et lille begyndelsesbogstav i alle teksterne, så tilføjer vi ordet til vores nye liste med ord med stort begyndelsesbogstav.
#
# NB. vi samler alle tekster i listen raw_texts med ' '.join(). På den måde bliver listen med tekster samlet omkring et mellemrum.
#
#
# #### Treasure Hunt for Proper Nouns
# Find the words that begin with capital letters but are not found with lowercase letters.
#
# Many of these words are capitalized because they appear after a period, and in that way, they are not what I would call "genuine" words with a capital letter.
#
# If you want to filter out the "unauthentic" words from your list, you can identify them by creating a loop and inserting a condition that checks if the words should be written in lowercase elsewhere in the texts, because if they are, then they are "unauthentic."
#
# Specifically, we do it by looping through the list of words with capital letters. If the word, which we manipulate with .lower() to consist only of lowercase letters, is not found with a lowercase initial letter in all the texts, then we add the word to our new list of words with a capital initial letter.
#
# Note: we collect all texts in the list raw_texts with ' '.join(). This way, the list of texts is combined with a space.

# %%
upper_case = []
for text in tales:
    upper_case_words = re.findall(r'[A-Z]\w+', text)
    for word in upper_case_words: 
        if word.lower() not in ' '.join(tales):
            upper_case.append(word)
set(upper_case)
# Out:
# {'ADVENTURES',
#  'ASHPUTTEL',
#  'Aha',
#  'Ashputtel',
#  'BANDY',
#  'BENJAMIN',
#  'Bewailing',
#  'Blackbird',
#  'Bravo',
#  'CATHERINE',
#  'CHANTICLEER',
#  'CROOK',
#  'Catherine',
#  'Caw',
#  'Chanticleer',
#  'Christendom',
#  'Christmas',
#  'Cinderella',
#  'Coxcomb',
#  'Crabb',
#  'Curdken',
#  'Dobbin',
#  'Dummling',
#  'ELSIE',
#  'Elsie',
#  'FREDERICK',
#  'FUNDEVOGEL',
#  'Falada',
#  'Finally',
#  'Fourthly',
#  'Frederick',
#  'Fundevogel',
#  'GRETEL',
#  'GRISLY',
#  'German',
#  'Gothel',
#  'Grete',
#  'Gretel',
#  'Grisly',
#  'Growler',
#  'HANS',
#  'HANSEL',
#  'HOLLE',
#  'HUNCHBACK',
#  'Hans',
#  'Hansel',
#  'Hark',
#  'Hearken',
#  'Heinel',
#  'Heinrich',
#  'Holiness',
#  'Holle',
#  'Hullo',
#  'Hurrah',
#  'ICHABOD',
#  'Ilsabill',
#  'Influenced',
#  'JEMMY',
#  'JEREMIAH',
#  'JOHN',
#  'JORINDA',
#  'JORINDEL',
#  'Jip',
#  'Jorinda',
#  'Jorindel',
#  'KNOWALL',
#  'KORBES',
#  'Kate',
#  'Kehrewit',
#  'Knowall',
#  'Korbes',
#  'Kywitt',
#  'LANGUAGES',
#  'MRS',
#  'Marleen',
#  'Mortal',
#  'Mrs',
#  'Oho',
#  'PARTLET',
#  'Partlet',
#  'Prithee',
#  'ROLAND',
#  'RUMPELSTILTSKIN',
#  'RUMPLESTILTSKIN',
#  'Readily',
#  'Roland',
#  'Rome',
#  'Rumpelstiltskin',
#  'SHANKS',
#  'SNOWDROP',
#  'SULTAN',
#  'Sanna',
#  'Snowdrop',
#  'Stromberg',
#  'Sultan',
#  'Sunday',
#  'Switzerland',
#  'TIMOTHY',
#  'Thomas',
#  'Tommy',
#  'Uncouth',
#  'Verily',
#  'Wallface',
#  'Witches'}

# %% [markdown]
# # Find tekstuddrag baseret på to søgeord og et interval
# Det sidste eksempel består i at finde tekstuddrag, der er kendetegnet ved at befinde sig mellem to udvalgte ord og ikke er længere end et udvalgt interval.
#
# Det kan f.eks. være relevant, hvis man er interesseret i at identificere tekstuddrag, hvor to vigtige karakterer eller begreber optræder i nærheden af hinanden.
#
# Det nye her er spørgsmålstegnet, der gør koden lazy.
#
#
#
# ### Find text excerpts based on two keywords and an interval
# The last example involves finding text excerpts characterized by being located between two selected words and not longer than a selected interval.
#
# This can be relevant, for example, if you are interested in identifying text excerpts where two important characters or concepts appear near each other.
#
# What's new here is the question mark, which makes the code lazy.

# %%
contexts2 = []
for text in tales:
    context = re.findall(r'\bGretel.+?\bHans\w*|\bHans.+?\bGretel\w*', text) # 
    contexts2.append(context)

# indsæt et max interval mellem første og andet ord 
contexts_within_interval = [item for item in contexts2 if len(item) <= 100]


list(zip(titles,contexts_within_interval))
# Out:
# [('THE GOLDEN BIRD', []),
#  ('HANS IN LUCK', []),
#  ('JORINDA AND JORINDEL', []),
#  ('THE TRAVELLING MUSICIANS', []),
#  ('OLD SULTAN', []),
#  ('THE STRAW, THE COAL, AND THE BEAN', []),
#  ('BRIAR ROSE', []),
#  ('THE DOG AND THE SPARROW', []),
#  ('THE TWELVE DANCING PRINCESSES', []),
#  ('THE FISHERMAN AND HIS WIFE', []),
#  ('THE WILLOW-WREN AND THE BEAR', []),
#  ('THE FROG-PRINCE', []),
#  ('CAT AND MOUSE IN PARTNERSHIP', []),
#  ('THE GOOSE-GIRL', []),
#  ('THE ADVENTURES OF CHANTICLEER AND PARTLET', []),
#  ('RAPUNZEL', []),
#  ('FUNDEVOGEL', []),
#  ('THE VALIANT LITTLE TAILOR', []),
#  ('HANSEL AND GRETEL',
#   ['Hansel and the girl Gretel',
#    'Gretel,’ said Hansel',
#    'Hansel and Gretel',
#    'Hansel and Gretel',
#    'Hansel and Gretel',
#    'Gretel shared her piece of bread with Hansel',
#    'Hansel said to Gretel',
#    'Hansel and Gretel',
#    'Hansel and Gretel',
#    'Hansel and Gretel',
#    'Hansel, but Gretel',
#    'Gretel, however, ran like lightning to Hansel',
#    'Hansel and Gretel']),
#  ('THE MOUSE, THE BIRD, AND THE SAUSAGE', []),
#  ('MOTHER HOLLE', []),
#  ('LITTLE RED-CAP [LITTLE RED RIDING HOOD]', []),
#  ('THE ROBBER BRIDEGROOM', []),
#  ('TOM THUMB', []),
#  ('RUMPELSTILTSKIN', []),
#  ('CLEVER GRETEL', []),
#  ('THE OLD MAN AND HIS GRANDSON', []),
#  ('THE LITTLE PEASANT', []),
#  ('FREDERICK AND CATHERINE', []),
#  ('SWEETHEART ROLAND', []),
#  ('SNOWDROP', []),
#  ('THE PINK', []),
#  ('CLEVER ELSIE', []),
#  ('THE MISER IN THE BUSH', []),
#  ('ASHPUTTEL', []),
#  ('THE WHITE SNAKE', []),
#  ('THE WOLF AND THE SEVEN LITTLE KIDS', []),
#  ('THE QUEEN BEE', []),
#  ('THE ELVES AND THE SHOEMAKER', []),
#  ('THE JUNIPER-TREE', []),
#  ('THE TURNIP', []),
#  ('CLEVER HANS',
#   ['Gretel.’ ‘Behave well, Hans',
#    'Hans.’ Hans comes to Gretel',
#    'Gretel presents Hans',
#    'Gretel.’ ‘Goodbye, Hans',
#    'Hans?’ ‘To Gretel',
#    'Gretel. ‘Good day, Gretel.’ ‘Good day, Hans',
#    'Hans with a knife. ‘Goodbye, Gretel',
#    'Hans. Where have you been?’ ‘With Gretel',
#    'Gretel give you?’ ‘Gave me a knife.’ ‘Where is the knife, Hans',
#    'Hans?’ ‘To Gretel',
#    'Gretel. ‘Good day, Gretel.’ ‘Good day, Hans',
#    'Hans with a young goat. ‘Goodbye, Gretel',
#    'Hans?’ ‘To Gretel',
#    'Gretel. ‘Good day, Gretel.’ ‘Good day, Hans',
#    'Hans with a piece of bacon. ‘Goodbye, Gretel',
#    'Hans?’ ‘To Gretel',
#    'Hans.’ Hans comes to Gretel',
#    'Gretel.’ ‘Good day, Hans',
#    'Gretel presents Hans',
#    'Gretel.’ ‘Goodbye, Hans',
#    'Hans?’ ‘To Gretel',
#    'Hans comes to Gretel',
#    'Gretel.’ ‘Good day, Hans',
#    'Gretel says to Hans',
#    'Hans takes Gretel',
#    'Hans. Where have you been?’ ‘With Gretel']),
#  ('THE THREE LANGUAGES', []),
#  ('THE FOX AND THE CAT', []),
#  ('THE FOUR CLEVER BROTHERS', []),
#  ('LILY AND THE LION', []),
#  ('THE FOX AND THE HORSE', []),
#  ('THE BLUE LIGHT', []),
#  ('THE RAVEN', []),
#  ('THE GOLDEN GOOSE', []),
#  ('THE WATER OF LIFE', []),
#  ('THE TWELVE HUNTSMEN', []),
#  ('THE KING OF THE GOLDEN MOUNTAIN', []),
#  ('DOCTOR KNOWALL', []),
#  ('THE SEVEN RAVENS', []),
#  ('THE WEDDING OF MRS FOX', []),
#  ('THE SALAD', []),
#  ('THE STORY OF THE YOUTH WHO WENT FORTH TO LEARN WHAT FEAR WAS', []),
#  ('KING GRISLY-BEARD', []),
#  ('IRON HANS', []),
#  ('CAT-SKIN', []),
#  ('SNOW-WHITE AND ROSE-RED', [])]
